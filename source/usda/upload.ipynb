# %%
from pymongo import MongoClient
import json

# %%
# upload foundation.json into local food collection

client = MongoClient('mongodb://localhost:27017/')
db = client.corpus

with open( './document/sample.json', 'r') as f:
    dados = json.load(f)

db.sample.insert_many(dados)

client.close()

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.corpus

# %%
with open( './document/sample.json', 'r') as f:
    dados = json.load(f)

db.sample.insert_many(dados)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /var/folders/9h/hf8rcs1940bdn1mbmbf2hs4r0000gn/T/ipykernel_31351/1509548015.py in <module>
#       2     dados = json.load(f)
#       3
# ----> 4 db.sample.insert_many(dados)
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     768         blk = _Bulk(self, ordered, bypass_document_validation)
#     769         blk.ops = [doc for doc in gen()]
# --> 770         blk.execute(write_concern, session=session)
#     771         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     772
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     531                 self.execute_no_results(sock_info, generator)
#     532         else:
# --> 533             return self.execute_command(generator, write_concern, session)
#     534
#     535
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     359
#     360         client = self.collection.database.client
# --> 361         with client._tmp_session(session) as s:
#     362             client._retry_with_session(
#     363                 self.is_retryable, retryable_bulk, s, self)
#
# /usr/local/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1946             return
#    1947
# -> 1948         s = self._ensure_session(session)
#    1949         if s:
#    1950             try:
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1933             # Don't make implicit sessions causally consistent. Applications
#    1934             # should always opt-in.
# -> 1935             return self.__start_session(True, causal_consistency=False)
#    1936         except (ConfigurationError, InvalidOperation):
#    1937             # Sessions not supported, or multiple users authenticated.
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1881
#    1882         # Raises ConfigurationError if sessions are not supported.
# -> 1883         server_session = self._get_server_session()
#    1884         opts = client_session.SessionOptions(**kwargs)
#    1885         return client_session.ClientSession(
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1919     def _get_server_session(self):
#    1920         """Internal: start or resume a _ServerSession."""
# -> 1921         return self._topology.get_server_session()
#    1922
#    1923     def _return_server_session(self, server_session, lock):
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/topology.py in get_server_session(self)
#     518             # Sessions are always supported in load balanced mode.
#     519             if not self._settings.load_balanced:
# --> 520                 session_timeout = self._check_session_support()
#     521             else:
#     522                 # Sessions never time out in load balanced mode.
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/topology.py in _check_session_support(self)
#     502                         None)
#     503             elif not self._description.readable_servers:
# --> 504                 self._select_servers_loop(
#     505                     readable_server_selector,
#     506                     self._settings.server_selection_timeout,
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     216             # No suitable servers.
#     217             if timeout == 0 or now > end_time:
# --> 218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
#     220                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: connection closed,connection closed,connection closed, Timeout: 30s, Topology Description: <TopologyDescription id: 619eac8e7ac79586fb258dab, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('cluster0-shard-00-00.cxvpd.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>, <ServerDescription ('cluster0-shard-00-01.cxvpd.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>, <ServerDescription ('cluster0-shard-00-02.cxvpd.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>]>

# %%
db.sample.updateMany({}, [
        {
          "$set": {
            "foodNutrients": {
              "$map": {
                "input": "$foodNutrients",
                "in": {
                  "_id": "$$this.nutrient.id",
                  "nutrient_name": "$$this.nutrient.name",
                  "nutrient_unit": "$$this.nutrient.unitName",
                  "nutrient_amount": "$$this.amount",
                },
              },
            },
          },
        },
      ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/9h/hf8rcs1940bdn1mbmbf2hs4r0000gn/T/ipykernel_31351/4191735255.py in <module>
# ----> 1 db.sample.updateMany({}, [
#       2         {
#       3           "$set": {
#       4             "foodNutrients": {
#       5               "$map": {
#
# ~/repos/corpo/backend/env/lib/python3.9/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3489                             "exists." %
#    3490                             self.__name)
# -> 3491         raise TypeError("'Collection' object is not callable. If you meant to "
#    3492                         "call the '%s' method on a 'Collection' object it is "
#    3493                         "failing because no such method exists." %
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'updateMany' method on a 'Collection' object it is failing because no such method exists.

# %%
# upload legacy.json into local food collection

client = MongoClient('mongodb://localhost:27017/')
db = client.corpus

with open( './csv/legacy.json', 'r') as f:
    dados = json.load(f)

db.food.insert_many(dados)
client.close()

# %%
cursor = db.data.find({}, projection={'_id':True, 'description':True, 'fdc_id':True })

# %%
from bson import ObjectId
import pandas as pd

udf = []
for item in cursor:
    item['_id'] =  str(item['_id'])
    udf.append(item)
    # udf['fdc_id'] =  item['fdc_id']
    # udf['description'] =  item['description']
    # break

udf
# Out:
# [{'_id': '61955b150dfbbc31a2fdf65f',
#   'fdc_id': 167512,
#   'description': 'Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough'},
#  {'_id': '61955d4c0dfbbc31a2fdf660',
#   'fdc_id': 167512,
#   'description': 'Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough'},
#  {'_id': '61955d4c0dfbbc31a2fdf661',
#   'fdc_id': 167513,
#   'description': 'Pillsbury, Cinnamon Rolls with Icing, refrigerated dough'},
#  {'_id': '61955d4c0dfbbc31a2fdf662',
#   'fdc_id': 167514,
#   'description': 'Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry'},
#  {'_id': '61955d4c0dfbbc31a2fdf663',
#   'fdc_id': 167515,
#   'description': 'George Weston Bakeries, Thomas English Muffins'},
#  {'_id': '61955d4c0dfbbc31a2fdf664',
#   'fdc_id': 167516,
#   'description': 'Waffles, buttermilk, frozen, ready-to-heat'},
#  {'_id': '61955d4c0dfbbc31a2fdf665',
#   'fdc_id': 167516,
#   'description': 'Waffles, buttermilk, frozen, ready-to-heat'},
#  {'_id': '61955d4c0dfbbc31a2fdf666',
#   'fdc_id': 167517,
#   'description': 'Waffle, buttermilk, frozen, ready-to-heat, toasted'},
#  {'_id': '61955d4c0dfbbc31a2fdf667',
#   'fdc_id': 167517,
#   'description': 'Waffle, buttermilk, frozen, ready-to-heat, toasted'},
#  {'_id': '61955d4c0dfbbc31a2fdf668',
#   'fdc_id': 167518,
#   'description': 'Waffle, buttermilk, frozen, ready-to-heat, microwaved'},
#  {'_id': '61955d4c0dfbbc31a2fdf669',
#   'fdc_id': 167519,
#   'description': 'Waffle, plain, frozen, ready-to-heat, microwave'},
#  {'_id': '61955d4c0dfbbc31a2fdf66a',
#   'fdc_id': 167520,
#   'description': 'Pie Crust, Cookie-type, Graham Cracker, Ready Crust'},
#  {'_id': '61955d4c0dfbbc31a2fdf66b',
#   'fdc_id': 167520,
#   'description': 'Pie Crust, Cookie-type, Graham Cracker, Ready Crust'},
#  {'_id': '61955d4c0dfbbc31a2fdf66c',
#   'fdc_id': 167521,
#   'description': 'Pie Crust, Cookie-type, Chocolate, Ready Crust'},
#  {'_id': '61955d4c0dfbbc31a2fdf66d',
#   'fdc_id': 167522,
#   'description': 'Pie, Dutch Apple, Commercially Prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf66e',
#   'fdc_id': 167522,
#   'description': 'Pie, Dutch Apple, Commercially Prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf66f',
#   'fdc_id': 167522,
#   'description': 'Pie, Dutch Apple, Commercially Prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf670',
#   'fdc_id': 167522,
#   'description': 'Pie, Dutch Apple, Commercially Prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf671',
#   'fdc_id': 167523,
#   'description': 'Pie crust, deep dish, frozen, unbaked, made with enriched flour'},
#  {'_id': '61955d4c0dfbbc31a2fdf672',
#   'fdc_id': 167524,
#   'description': 'Waffles, chocolate chip, frozen, ready-to-heat'},
#  {'_id': '61955d4c0dfbbc31a2fdf673',
#   'fdc_id': 167525,
#   'description': 'Tostada shells, corn'},
#  {'_id': '61955d4c0dfbbc31a2fdf674',
#   'fdc_id': 167525,
#   'description': 'Tostada shells, corn'},
#  {'_id': '61955d4c0dfbbc31a2fdf675',
#   'fdc_id': 167526,
#   'description': 'Bread, salvadoran sweet cheese (quesadilla salvadorena)'},
#  {'_id': '61955d4c0dfbbc31a2fdf676',
#   'fdc_id': 167526,
#   'description': 'Bread, salvadoran sweet cheese (quesadilla salvadorena)'},
#  {'_id': '61955d4c0dfbbc31a2fdf677',
#   'fdc_id': 167527,
#   'description': 'Bread, pound cake type, pan de torta salvadoran'},
#  {'_id': '61955d4c0dfbbc31a2fdf678',
#   'fdc_id': 167527,
#   'description': 'Bread, pound cake type, pan de torta salvadoran'},
#  {'_id': '61955d4c0dfbbc31a2fdf679',
#   'fdc_id': 167528,
#   'description': 'Pastry, Pastelitos de Guava (guava pastries)'},
#  {'_id': '61955d4c0dfbbc31a2fdf67a',
#   'fdc_id': 167529,
#   'description': 'Crackers, snack, Goya Crackers'},
#  {'_id': '61955d4c0dfbbc31a2fdf67b',
#   'fdc_id': 167529,
#   'description': 'Crackers, snack, Goya Crackers'},
#  {'_id': '61955d4c0dfbbc31a2fdf67c',
#   'fdc_id': 167530,
#   'description': 'Crackers, cream, Gamesa Sabrosas'},
#  {'_id': '61955d4c0dfbbc31a2fdf67d',
#   'fdc_id': 167530,
#   'description': 'Crackers, cream, Gamesa Sabrosas'},
#  {'_id': '61955d4c0dfbbc31a2fdf67e',
#   'fdc_id': 167531,
#   'description': 'Crackers, cream, La Moderna Rikis Cream Crackers'},
#  {'_id': '61955d4c0dfbbc31a2fdf67f',
#   'fdc_id': 167531,
#   'description': 'Crackers, cream, La Moderna Rikis Cream Crackers'},
#  {'_id': '61955d4c0dfbbc31a2fdf680',
#   'fdc_id': 167532,
#   'description': 'Bread, white wheat'},
#  {'_id': '61955d4c0dfbbc31a2fdf681',
#   'fdc_id': 167533,
#   'description': 'Bagels, wheat'},
#  {'_id': '61955d4c0dfbbc31a2fdf682',
#   'fdc_id': 167534,
#   'description': 'Cream puff, eclair, custard or cream filled, iced'},
#  {'_id': '61955d4c0dfbbc31a2fdf683',
#   'fdc_id': 167535,
#   'description': 'Tortillas, ready-to-bake or -fry, flour, shelf stable'},
#  {'_id': '61955d4c0dfbbc31a2fdf684',
#   'fdc_id': 167535,
#   'description': 'Tortillas, ready-to-bake or -fry, flour, shelf stable'},
#  {'_id': '61955d4c0dfbbc31a2fdf685',
#   'fdc_id': 167536,
#   'description': 'Snacks, beef jerky, chopped and formed'},
#  {'_id': '61955d4c0dfbbc31a2fdf686',
#   'fdc_id': 167536,
#   'description': 'Snacks, beef jerky, chopped and formed'},
#  {'_id': '61955d4c0dfbbc31a2fdf687',
#   'fdc_id': 167537,
#   'description': 'Snacks, corn-based, extruded, chips, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf688',
#   'fdc_id': 167537,
#   'description': 'Snacks, corn-based, extruded, chips, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf689',
#   'fdc_id': 167537,
#   'description': 'Snacks, corn-based, extruded, chips, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf68a',
#   'fdc_id': 167538,
#   'description': 'Snacks, corn-based, extruded, chips, barbecue-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf68b',
#   'fdc_id': 167538,
#   'description': 'Snacks, corn-based, extruded, chips, barbecue-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf68c',
#   'fdc_id': 167539,
#   'description': 'Snacks, corn-based, extruded, cones, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf68d',
#   'fdc_id': 167540,
#   'description': 'Snacks, fruit leather, pieces'},
#  {'_id': '61955d4c0dfbbc31a2fdf68e',
#   'fdc_id': 167540,
#   'description': 'Snacks, fruit leather, pieces'},
#  {'_id': '61955d4c0dfbbc31a2fdf68f',
#   'fdc_id': 167540,
#   'description': 'Snacks, fruit leather, pieces'},
#  {'_id': '61955d4c0dfbbc31a2fdf690',
#   'fdc_id': 167541,
#   'description': 'Snacks, fruit leather, rolls'},
#  {'_id': '61955d4c0dfbbc31a2fdf691',
#   'fdc_id': 167541,
#   'description': 'Snacks, fruit leather, rolls'},
#  {'_id': '61955d4c0dfbbc31a2fdf692',
#   'fdc_id': 167542,
#   'description': 'Snacks, granola bars, hard, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf693',
#   'fdc_id': 167542,
#   'description': 'Snacks, granola bars, hard, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf694',
#   'fdc_id': 167542,
#   'description': 'Snacks, granola bars, hard, plain'},
#  {'_id': '61955d4c0dfbbc31a2fdf695',
#   'fdc_id': 167543,
#   'description': 'Snacks, granola bars, hard, almond'},
#  {'_id': '61955d4c0dfbbc31a2fdf696',
#   'fdc_id': 167543,
#   'description': 'Snacks, granola bars, hard, almond'},
#  {'_id': '61955d4c0dfbbc31a2fdf697',
#   'fdc_id': 167544,
#   'description': 'Snacks, granola bars, soft, uncoated, raisin'},
#  {'_id': '61955d4c0dfbbc31a2fdf698',
#   'fdc_id': 167544,
#   'description': 'Snacks, granola bars, soft, uncoated, raisin'},
#  {'_id': '61955d4c0dfbbc31a2fdf699',
#   'fdc_id': 167545,
#   'description': 'Snacks, granola bars, soft, coated, milk chocolate coating, chocolate chip'},
#  {'_id': '61955d4c0dfbbc31a2fdf69a',
#   'fdc_id': 167545,
#   'description': 'Snacks, granola bars, soft, coated, milk chocolate coating, chocolate chip'},
#  {'_id': '61955d4c0dfbbc31a2fdf69b',
#   'fdc_id': 167546,
#   'description': 'Candies, honey-combed, with peanut butter'},
#  {'_id': '61955d4c0dfbbc31a2fdf69c',
#   'fdc_id': 167547,
#   'description': 'Snacks, granola bars, soft, coated, milk chocolate coating, peanut butter'},
#  {'_id': '61955d4c0dfbbc31a2fdf69d',
#   'fdc_id': 167547,
#   'description': 'Snacks, granola bars, soft, coated, milk chocolate coating, peanut butter'},
#  {'_id': '61955d4c0dfbbc31a2fdf69e',
#   'fdc_id': 167548,
#   'description': 'Snacks, granola bars, soft, uncoated, peanut butter and chocolate chip'},
#  {'_id': '61955d4c0dfbbc31a2fdf69f',
#   'fdc_id': 167549,
#   'description': 'Snacks, popcorn, oil-popped, microwave, regular flavor, no trans fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a0',
#   'fdc_id': 167549,
#   'description': 'Snacks, popcorn, oil-popped, microwave, regular flavor, no trans fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a1',
#   'fdc_id': 167550,
#   'description': 'Snacks, popcorn, cakes'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a2',
#   'fdc_id': 167550,
#   'description': 'Snacks, popcorn, cakes'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a3',
#   'fdc_id': 167551,
#   'description': 'Snacks, popcorn, caramel-coated, with peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a4',
#   'fdc_id': 167551,
#   'description': 'Snacks, popcorn, caramel-coated, with peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a5',
#   'fdc_id': 167552,
#   'description': 'Snacks, popcorn, caramel-coated, without peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a6',
#   'fdc_id': 167553,
#   'description': 'Snacks, potato chips, made from dried potatoes, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a7',
#   'fdc_id': 167553,
#   'description': 'Snacks, potato chips, made from dried potatoes, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a8',
#   'fdc_id': 167554,
#   'description': 'Snacks, potato chips, made from dried potatoes, sour-cream and onion-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf6a9',
#   'fdc_id': 167554,
#   'description': 'Snacks, potato chips, made from dried potatoes, sour-cream and onion-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf6aa',
#   'fdc_id': 167555,
#   'description': 'Snacks, pretzels, hard, plain, salted'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ab',
#   'fdc_id': 167555,
#   'description': 'Snacks, pretzels, hard, plain, salted'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ac',
#   'fdc_id': 167556,
#   'description': "Snacks, pretzels, hard, confectioner's coating, chocolate-flavor"},
#  {'_id': '61955d4c0dfbbc31a2fdf6ad',
#   'fdc_id': 167556,
#   'description': "Snacks, pretzels, hard, confectioner's coating, chocolate-flavor"},
#  {'_id': '61955d4c0dfbbc31a2fdf6ae',
#   'fdc_id': 167557,
#   'description': 'Snacks, rice cakes, brown rice, sesame seed'},
#  {'_id': '61955d4c0dfbbc31a2fdf6af',
#   'fdc_id': 167557,
#   'description': 'Snacks, rice cakes, brown rice, sesame seed'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b0',
#   'fdc_id': 167558,
#   'description': 'Snacks, tortilla chips, plain, white corn, salted'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b1',
#   'fdc_id': 167558,
#   'description': 'Snacks, tortilla chips, plain, white corn, salted'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b2',
#   'fdc_id': 167559,
#   'description': 'Snacks, tortilla chips, nacho cheese'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b3',
#   'fdc_id': 167560,
#   'description': 'Snacks, tortilla chips, ranch-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b4',
#   'fdc_id': 167560,
#   'description': 'Snacks, tortilla chips, ranch-flavor'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b5',
#   'fdc_id': 167561,
#   'description': 'Snacks, trail mix, regular'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b6',
#   'fdc_id': 167561,
#   'description': 'Snacks, trail mix, regular'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b7',
#   'fdc_id': 167561,
#   'description': 'Snacks, trail mix, regular'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b8',
#   'fdc_id': 167562,
#   'description': 'Candies, ALMOND JOY Candy Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6b9',
#   'fdc_id': 167562,
#   'description': 'Candies, ALMOND JOY Candy Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ba',
#   'fdc_id': 167563,
#   'description': 'Candies, TWIZZLERS CHERRY BITES'},
#  {'_id': '61955d4c0dfbbc31a2fdf6bb',
#   'fdc_id': 167564,
#   'description': "Candies, NESTLE, BIT-O'-HONEY Candy Chews"},
#  {'_id': '61955d4c0dfbbc31a2fdf6bc',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6bd',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6be',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6bf',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c0',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c1',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c2',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c3',
#   'fdc_id': 167565,
#   'description': 'Candies, NESTLE, BUTTERFINGER Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c4',
#   'fdc_id': 167566,
#   'description': 'Candies, caramels, chocolate-flavor roll'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c5',
#   'fdc_id': 167566,
#   'description': 'Candies, caramels, chocolate-flavor roll'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c6',
#   'fdc_id': 167566,
#   'description': 'Candies, caramels, chocolate-flavor roll'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c7',
#   'fdc_id': 167567,
#   'description': 'Baking chocolate, unsweetened, liquid'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c8',
#   'fdc_id': 167568,
#   'description': 'Baking chocolate, unsweetened, squares'},
#  {'_id': '61955d4c0dfbbc31a2fdf6c9',
#   'fdc_id': 167568,
#   'description': 'Baking chocolate, unsweetened, squares'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ca',
#   'fdc_id': 167568,
#   'description': 'Baking chocolate, unsweetened, squares'},
#  {'_id': '61955d4c0dfbbc31a2fdf6cb',
#   'fdc_id': 167569,
#   'description': "Candies, confectioner's coating, yogurt"},
#  {'_id': '61955d4c0dfbbc31a2fdf6cc',
#   'fdc_id': 167570,
#   'description': "Candies, confectioner's coating, peanut butter"},
#  {'_id': '61955d4c0dfbbc31a2fdf6cd',
#   'fdc_id': 167570,
#   'description': "Candies, confectioner's coating, peanut butter"},
#  {'_id': '61955d4c0dfbbc31a2fdf6ce',
#   'fdc_id': 167571,
#   'description': 'Candies, white chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6cf',
#   'fdc_id': 167571,
#   'description': 'Candies, white chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d0',
#   'fdc_id': 167571,
#   'description': 'Candies, white chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d1',
#   'fdc_id': 167572,
#   'description': 'Ice creams, vanilla, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d2',
#   'fdc_id': 167573,
#   'description': 'Ice creams, vanilla, rich'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d3',
#   'fdc_id': 167574,
#   'description': 'Desserts, flan, caramel custard, prepared-from-recipe'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d4',
#   'fdc_id': 167574,
#   'description': 'Desserts, flan, caramel custard, prepared-from-recipe'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d5',
#   'fdc_id': 167575,
#   'description': 'Ice creams, vanilla'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d6',
#   'fdc_id': 167576,
#   'description': 'Ice creams, vanilla, light, soft-serve'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d7',
#   'fdc_id': 167577,
#   'description': 'Sherbet, orange'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d8',
#   'fdc_id': 167577,
#   'description': 'Sherbet, orange'},
#  {'_id': '61955d4c0dfbbc31a2fdf6d9',
#   'fdc_id': 167578,
#   'description': 'Candies, fudge, peanut butter, prepared-from-recipe'},
#  {'_id': '61955d4c0dfbbc31a2fdf6da',
#   'fdc_id': 167579,
#   'description': 'Candies, fudge, vanilla, prepared-from-recipe'},
#  {'_id': '61955d4c0dfbbc31a2fdf6db',
#   'fdc_id': 167580,
#   'description': 'Candies, fudge, vanilla with nuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6dc',
#   'fdc_id': 167581,
#   'description': 'Candies, NESTLE, GOOBERS Chocolate Covered Peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6dd',
#   'fdc_id': 167581,
#   'description': 'Candies, NESTLE, GOOBERS Chocolate Covered Peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6de',
#   'fdc_id': 167581,
#   'description': 'Candies, NESTLE, GOOBERS Chocolate Covered Peanuts'},
#  {'_id': '61955d4c0dfbbc31a2fdf6df',
#   'fdc_id': 167582,
#   'description': 'Candies, NESTLE, BABY RUTH Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e0',
#   'fdc_id': 167582,
#   'description': 'Candies, NESTLE, BABY RUTH Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e1',
#   'fdc_id': 167583,
#   'description': 'Candies, TWIZZLERS Strawberry Twists Candy'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e2',
#   'fdc_id': 167584,
#   'description': 'Syrups, table blends, pancake, with butter'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e3',
#   'fdc_id': 167585,
#   'description': 'Ice creams, chocolate, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e4',
#   'fdc_id': 167585,
#   'description': 'Ice creams, chocolate, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e5',
#   'fdc_id': 167586,
#   'description': 'Candies, NESTLE, CHUNKY Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e6',
#   'fdc_id': 167587,
#   'description': 'Candies, milk chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e7',
#   'fdc_id': 167587,
#   'description': 'Candies, milk chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e8',
#   'fdc_id': 167587,
#   'description': 'Candies, milk chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf6e9',
#   'fdc_id': 167588,
#   'description': 'Puddings, banana, dry mix, instant, prepared with 2% milk'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ea',
#   'fdc_id': 167589,
#   'description': 'Puddings, banana, dry mix, regular, prepared with 2% milk'},
#  {'_id': '61955d4c0dfbbc31a2fdf6eb',
#   'fdc_id': 167590,
#   'description': "Andrea's, Gluten Free Soft Dinner Roll"},
#  {'_id': '61955d4c0dfbbc31a2fdf6ec',
#   'fdc_id': 167591,
#   'description': 'Crunchmaster, Multi-Grain Crisps, Snack Crackers, Gluten-Free'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ed',
#   'fdc_id': 167592,
#   'description': 'Glutino, Gluten Free Cookies, Chocolate Vanilla Creme'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ee',
#   'fdc_id': 167593,
#   'description': 'Glutino, Gluten Free Cookies, Vanilla Creme'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ef',
#   'fdc_id': 167594,
#   'description': 'Pepperidge Farm, Goldfish, Baked Snack Crackers, Original'},
#  {'_id': '61955d4c0dfbbc31a2fdf6f0',
#   'fdc_id': 167595,
#   'description': 'Pepperidge Farm, Goldfish, Baked Snack Crackers, Parmesan'},
#  {'_id': '61955d4c0dfbbc31a2fdf6f1',
#   'fdc_id': 167596,
#   'description': 'Pepperidge Farm, Goldfish, Baked Snack Crackers, Pizza'},
#  {'_id': '61955d4c0dfbbc31a2fdf6f2',
#   'fdc_id': 167597,
#   'description': "Rudi's, Gluten-Free Bakery, Original Sandwich Bread"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f3',
#   'fdc_id': 167598,
#   'description': "Udi's, Gluten Free, Soft & Delicious White Sandwich Bread"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f4',
#   'fdc_id': 167599,
#   'description': "Udi's, Gluten Free, Soft & Hearty Whole Grain Bread"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f5',
#   'fdc_id': 167600,
#   'description': "Udi's, Gluten Free, Whole Grain Dinner Rolls"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f6',
#   'fdc_id': 167601,
#   'description': "Van's, Gluten Free, Totally Original Pancakes"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f7',
#   'fdc_id': 167601,
#   'description': "Van's, Gluten Free, Totally Original Pancakes"},
#  {'_id': '61955d4c0dfbbc31a2fdf6f8',
#   'fdc_id': 167602,
#   'description': 'Seaweed, Canadian Cultivated EMI-TSUNOMATA, dry'},
#  {'_id': '61955d4c0dfbbc31a2fdf6f9',
#   'fdc_id': 167603,
#   'description': 'Seaweed, Canadian Cultivated EMI-TSUNOMATA, rehydrated'},
#  {'_id': '61955d4c0dfbbc31a2fdf6fa',
#   'fdc_id': 167604,
#   'description': 'Potatoes, hash brown, refrigerated, unprepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf6fb',
#   'fdc_id': 167605,
#   'description': 'Potatoes, hash brown, refrigerated, prepared, pan-fried in canola oil'},
#  {'_id': '61955d4c0dfbbc31a2fdf6fc',
#   'fdc_id': 167606,
#   'description': 'Sweet Potatoes, french fried, frozen as packaged, salt added in processing'},
#  {'_id': '61955d4c0dfbbc31a2fdf6fd',
#   'fdc_id': 167632,
#   'description': 'Squash, Indian, cooked, boiled (Navajo)'},
#  {'_id': '61955d4c0dfbbc31a2fdf6fe',
#   'fdc_id': 167633,
#   'description': 'Bread, kneel down (Navajo)'},
#  {'_id': '61955d4c0dfbbc31a2fdf6ff',
#   'fdc_id': 167634,
#   'description': 'Mutton, cooked, roasted (Navajo)'},
#  {'_id': '61955d4c0dfbbc31a2fdf700',
#   'fdc_id': 167635,
#   'description': 'Frybread, made with lard (Navajo)'},
#  {'_id': '61955d4c0dfbbc31a2fdf701',
#   'fdc_id': 167636,
#   'description': 'Tamales (Navajo)'},
#  {'_id': '61955d4c0dfbbc31a2fdf702',
#   'fdc_id': 167653,
#   'description': 'Corn, dried, yellow (Northern Plains Indians)'},
#  {'_id': '61955d4c0dfbbc31a2fdf703',
#   'fdc_id': 167657,
#   'description': 'ON THE BORDER, soft taco with ground beef, cheese and lettuce'},
#  {'_id': '61955d4c0dfbbc31a2fdf704',
#   'fdc_id': 167658,
#   'description': 'Restaurant, Mexican, soft taco with ground beef, cheese and lettuce'},
#  {'_id': '61955d4c0dfbbc31a2fdf705',
#   'fdc_id': 167658,
#   'description': 'Restaurant, Mexican, soft taco with ground beef, cheese and lettuce'},
#  {'_id': '61955d4c0dfbbc31a2fdf706',
#   'fdc_id': 167658,
#   'description': 'Restaurant, Mexican, soft taco with ground beef, cheese and lettuce'},
#  {'_id': '61955d4c0dfbbc31a2fdf707',
#   'fdc_id': 167658,
#   'description': 'Restaurant, Mexican, soft taco with ground beef, cheese and lettuce'},
#  {'_id': '61955d4c0dfbbc31a2fdf708',
#   'fdc_id': 167659,
#   'description': 'Restaurant, Latino, chicken and rice, entree, prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf709',
#   'fdc_id': 167660,
#   'description': 'Restaurant, Latino, empanadas, beef, prepared'},
#  {'_id': '61955d4c0dfbbc31a2fdf70a',
#   'fdc_id': 167661,
#   'description': 'Restaurant, Latino, pupusas con frijoles (pupusas, bean)'},
#  {'_id': '61955d4c0dfbbc31a2fdf70b',
#   'fdc_id': 167662,
#   'description': 'Restaurant, Latino, pupusas con queso (pupusas, cheese)'},
#  {'_id': '61955d4c0dfbbc31a2fdf70c',
#   'fdc_id': 167663,
#   'description': 'Restaurant, Latino, pupusas del cerdo (pupusas, pork)'},
#  {'_id': '61955d4c0dfbbc31a2fdf70d',
#   'fdc_id': 167664,
#   'description': 'Restaurant, Latino, tamale, corn'},
#  {'_id': '61955d4c0dfbbc31a2fdf70e',
#   'fdc_id': 167665,
#   'description': 'Restaurant, Mexican, spanish rice'},
#  {'_id': '61955d4c0dfbbc31a2fdf70f',
#   'fdc_id': 167666,
#   'description': 'Restaurant, Mexican, refried beans'},
#  {'_id': '61955d4c0dfbbc31a2fdf710',
#   'fdc_id': 167667,
#   'description': 'Restaurant, Chinese, egg rolls, assorted'},
#  {'_id': '61955d4c0dfbbc31a2fdf711',
#   'fdc_id': 167668,
#   'description': 'Restaurant, Chinese, fried rice, without meat'},
#  {'_id': '61955d4c0dfbbc31a2fdf712',
#   'fdc_id': 167669,
#   'description': 'CRACKER BARREL, steak fries'},
#  {'_id': '61955d4c0dfbbc31a2fdf713',
#   'fdc_id': 167670,
#   'description': 'CRACKER BARREL, grilled sirloin steak'},
#  {'_id': '61955d4c0dfbbc31a2fdf714',
#   'fdc_id': 167671,
#   'description': "CRACKER BARREL, macaroni n' cheese plate, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf715',
#   'fdc_id': 167671,
#   'description': "CRACKER BARREL, macaroni n' cheese plate, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf716',
#   'fdc_id': 167672,
#   'description': "DENNY'S, french fries"},
#  {'_id': '61955d4c0dfbbc31a2fdf717',
#   'fdc_id': 167673,
#   'description': "DENNY'S, top sirloin steak"},
#  {'_id': '61955d4c0dfbbc31a2fdf718',
#   'fdc_id': 167674,
#   'description': 'Restaurant, Chinese, lemon chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf719',
#   'fdc_id': 167674,
#   'description': 'Restaurant, Chinese, lemon chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf71a',
#   'fdc_id': 167675,
#   'description': "Restaurant, Chinese, general tso's chicken"},
#  {'_id': '61955d4c0dfbbc31a2fdf71b',
#   'fdc_id': 167675,
#   'description': "Restaurant, Chinese, general tso's chicken"},
#  {'_id': '61955d4c0dfbbc31a2fdf71c',
#   'fdc_id': 167676,
#   'description': 'Restaurant, Chinese, kung pao chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf71d',
#   'fdc_id': 167677,
#   'description': 'Restaurant, Chinese, vegetable lo mein, without meat'},
#  {'_id': '61955d4c0dfbbc31a2fdf71e',
#   'fdc_id': 167677,
#   'description': 'Restaurant, Chinese, vegetable lo mein, without meat'},
#  {'_id': '61955d4c0dfbbc31a2fdf71f',
#   'fdc_id': 167678,
#   'description': 'Restaurant, Chinese, chicken and vegetables'},
#  {'_id': '61955d4c0dfbbc31a2fdf720',
#   'fdc_id': 167678,
#   'description': 'Restaurant, Chinese, chicken and vegetables'},
#  {'_id': '61955d4c0dfbbc31a2fdf721',
#   'fdc_id': 167679,
#   'description': 'Restaurant, Chinese, orange chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf722',
#   'fdc_id': 167679,
#   'description': 'Restaurant, Chinese, orange chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf723',
#   'fdc_id': 167680,
#   'description': 'Restaurant, Italian, spaghetti with meat sauce'},
#  {'_id': '61955d4c0dfbbc31a2fdf724',
#   'fdc_id': 167681,
#   'description': 'Beverages, fruit-flavored drink, dry powdered mix, low calorie, with aspartame'},
#  {'_id': '61955d4c0dfbbc31a2fdf725',
#   'fdc_id': 167682,
#   'description': 'Pectin, liquid'},
#  {'_id': '61955d4c0dfbbc31a2fdf726',
#   'fdc_id': 167683,
#   'description': 'Frozen novelties, ice cream type, vanilla ice cream, light, no sugar added, chocolate coated'},
#  {'_id': '61955d4c0dfbbc31a2fdf727',
#   'fdc_id': 167684,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf728',
#   'fdc_id': 167684,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf729',
#   'fdc_id': 167685,
#   'description': 'Bologna, beef and pork, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf72a',
#   'fdc_id': 167685,
#   'description': 'Bologna, beef and pork, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf72b',
#   'fdc_id': 167685,
#   'description': 'Bologna, beef and pork, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf72c',
#   'fdc_id': 167685,
#   'description': 'Bologna, beef and pork, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf72d',
#   'fdc_id': 167685,
#   'description': 'Bologna, beef and pork, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf72e',
#   'fdc_id': 167686,
#   'description': 'Milk dessert, frozen, milk-fat free, chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf72f',
#   'fdc_id': 167687,
#   'description': 'Whipped topping, frozen, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf730',
#   'fdc_id': 167688,
#   'description': 'Cream substitute, powdered, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf731',
#   'fdc_id': 167688,
#   'description': 'Cream substitute, powdered, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf732',
#   'fdc_id': 167689,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Peanut Butter Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf733',
#   'fdc_id': 167689,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Peanut Butter Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf734',
#   'fdc_id': 167689,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Peanut Butter Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf735',
#   'fdc_id': 167690,
#   'description': 'Babyfood, apple yogurt dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf736',
#   'fdc_id': 167690,
#   'description': 'Babyfood, apple yogurt dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf737',
#   'fdc_id': 167690,
#   'description': 'Babyfood, apple yogurt dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf738',
#   'fdc_id': 167691,
#   'description': 'Vegetable oil-butter spread, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf739',
#   'fdc_id': 167691,
#   'description': 'Vegetable oil-butter spread, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf73a',
#   'fdc_id': 167692,
#   'description': 'Salad dressing, blue or roquefort cheese dressing, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf73b',
#   'fdc_id': 167692,
#   'description': 'Salad dressing, blue or roquefort cheese dressing, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf73c',
#   'fdc_id': 167693,
#   'description': 'Salad dressing, french dressing, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf73d',
#   'fdc_id': 167693,
#   'description': 'Salad dressing, french dressing, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf73e',
#   'fdc_id': 167694,
#   'description': 'Sausage, turkey and pork, fresh, bulk, patty or link, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf73f',
#   'fdc_id': 167694,
#   'description': 'Sausage, turkey and pork, fresh, bulk, patty or link, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf740',
#   'fdc_id': 167694,
#   'description': 'Sausage, turkey and pork, fresh, bulk, patty or link, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf741',
#   'fdc_id': 167694,
#   'description': 'Sausage, turkey and pork, fresh, bulk, patty or link, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf742',
#   'fdc_id': 167695,
#   'description': 'Mayonnaise, made with tofu'},
#  {'_id': '61955d4c0dfbbc31a2fdf743',
#   'fdc_id': 167695,
#   'description': 'Mayonnaise, made with tofu'},
#  {'_id': '61955d4c0dfbbc31a2fdf744',
#   'fdc_id': 167696,
#   'description': 'Frankfurter, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf745',
#   'fdc_id': 167696,
#   'description': 'Frankfurter, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf746',
#   'fdc_id': 167697,
#   'description': 'Milk, buttermilk, fluid, cultured, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf747',
#   'fdc_id': 167697,
#   'description': 'Milk, buttermilk, fluid, cultured, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf748',
#   'fdc_id': 167698,
#   'description': 'Pork sausage rice links, brown and serve, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf749',
#   'fdc_id': 167698,
#   'description': 'Pork sausage rice links, brown and serve, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdf74a',
#   'fdc_id': 167699,
#   'description': 'Salad dressing, blue or roquefort cheese dressing, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf74b',
#   'fdc_id': 167699,
#   'description': 'Salad dressing, blue or roquefort cheese dressing, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf74c',
#   'fdc_id': 167700,
#   'description': 'Salad Dressing, mayonnaise-like, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf74d',
#   'fdc_id': 167700,
#   'description': 'Salad Dressing, mayonnaise-like, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf74e',
#   'fdc_id': 167701,
#   'description': 'Candies, MARS SNACKFOOD US, MILKY WAY Midnight Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf74f',
#   'fdc_id': 167701,
#   'description': 'Candies, MARS SNACKFOOD US, MILKY WAY Midnight Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf750',
#   'fdc_id': 167701,
#   'description': 'Candies, MARS SNACKFOOD US, MILKY WAY Midnight Bar'},
#  {'_id': '61955d4c0dfbbc31a2fdf751',
#   'fdc_id': 167702,
#   'description': 'Oil, flaxseed, cold pressed'},
#  {'_id': '61955d4c0dfbbc31a2fdf752',
#   'fdc_id': 167702,
#   'description': 'Oil, flaxseed, cold pressed'},
#  {'_id': '61955d4c0dfbbc31a2fdf753',
#   'fdc_id': 167703,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, lactose reduced'},
#  {'_id': '61955d4c0dfbbc31a2fdf754',
#   'fdc_id': 167703,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, lactose reduced'},
#  {'_id': '61955d4c0dfbbc31a2fdf755',
#   'fdc_id': 167704,
#   'description': 'Salad dressing, bacon and tomato'},
#  {'_id': '61955d4c0dfbbc31a2fdf756',
#   'fdc_id': 167704,
#   'description': 'Salad dressing, bacon and tomato'},
#  {'_id': '61955d4c0dfbbc31a2fdf757',
#   'fdc_id': 167705,
#   'description': 'Cheese, parmesan, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf758',
#   'fdc_id': 167705,
#   'description': 'Cheese, parmesan, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf759',
#   'fdc_id': 167706,
#   'description': 'Jams, preserves, marmalade, reduced sugar'},
#  {'_id': '61955d4c0dfbbc31a2fdf75a',
#   'fdc_id': 167707,
#   'description': 'Beverages, fruit-flavored drink, powder, with high vitamin C with other added vitamins, low calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf75b',
#   'fdc_id': 167708,
#   'description': 'Tomato and vegetable juice, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf75c',
#   'fdc_id': 167708,
#   'description': 'Tomato and vegetable juice, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf75d',
#   'fdc_id': 167709,
#   'description': 'Turkey, wing, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf75e',
#   'fdc_id': 167709,
#   'description': 'Turkey, wing, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf75f',
#   'fdc_id': 167710,
#   'description': 'Turkey, drumstick, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf760',
#   'fdc_id': 167710,
#   'description': 'Turkey, drumstick, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf761',
#   'fdc_id': 167711,
#   'description': 'Beverages, Chocolate-flavored drink, whey and milk based'},
#  {'_id': '61955d4c0dfbbc31a2fdf762',
#   'fdc_id': 167711,
#   'description': 'Beverages, Chocolate-flavored drink, whey and milk based'},
#  {'_id': '61955d4c0dfbbc31a2fdf763',
#   'fdc_id': 167712,
#   'description': 'Pork, cured, bacon, cooked, broiled, pan-fried or roasted, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf764',
#   'fdc_id': 167712,
#   'description': 'Pork, cured, bacon, cooked, broiled, pan-fried or roasted, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf765',
#   'fdc_id': 167713,
#   'description': 'Turkey, light or dark meat, smoked, cooked, skin and bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf766',
#   'fdc_id': 167713,
#   'description': 'Turkey, light or dark meat, smoked, cooked, skin and bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf767',
#   'fdc_id': 167713,
#   'description': 'Turkey, light or dark meat, smoked, cooked, skin and bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdf768',
#   'fdc_id': 167715,
#   'description': "Cereals ready-to-eat, POST, Shredded Wheat n' Bran, spoon-size"},
#  {'_id': '61955d4c0dfbbc31a2fdf769',
#   'fdc_id': 167716,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, with vegetables'},
#  {'_id': '61955d4c0dfbbc31a2fdf76a',
#   'fdc_id': 167716,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, with vegetables'},
#  {'_id': '61955d4c0dfbbc31a2fdf76b',
#   'fdc_id': 167717,
#   'description': 'Yeast extract spread'},
#  {'_id': '61955d4c0dfbbc31a2fdf76c',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf76d',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf76e',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf76f',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf770',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf771',
#   'fdc_id': 167718,
#   'description': 'Babyfood, juice, pear'},
#  {'_id': '61955d4c0dfbbc31a2fdf772',
#   'fdc_id': 167719,
#   'description': 'Chicken, meatless, breaded, fried'},
#  {'_id': '61955d4c0dfbbc31a2fdf773',
#   'fdc_id': 167719,
#   'description': 'Chicken, meatless, breaded, fried'},
#  {'_id': '61955d4c0dfbbc31a2fdf774',
#   'fdc_id': 167719,
#   'description': 'Chicken, meatless, breaded, fried'},
#  {'_id': '61955d4c0dfbbc31a2fdf775',
#   'fdc_id': 167720,
#   'description': 'Babyfood, meat, beef with vegetables, toddler'},
#  {'_id': '61955d4c0dfbbc31a2fdf776',
#   'fdc_id': 167721,
#   'description': 'Frozen novelties, juice type, juice with cream'},
#  {'_id': '61955d4c0dfbbc31a2fdf777',
#   'fdc_id': 167722,
#   'description': 'Tofu yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdf778',
#   'fdc_id': 167723,
#   'description': 'Alcoholic beverage, rice (sake)'},
#  {'_id': '61955d4c0dfbbc31a2fdf779',
#   'fdc_id': 167724,
#   'description': 'Millet, puffed'},
#  {'_id': '61955d4c0dfbbc31a2fdf77a',
#   'fdc_id': 167725,
#   'description': 'Cereals ready-to-eat, OAT BRAN FLAKES, HEALTH VALLEY'},
#  {'_id': '61955d4c0dfbbc31a2fdf77b',
#   'fdc_id': 167726,
#   'description': 'Babyfood, mixed fruit yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf77c',
#   'fdc_id': 167726,
#   'description': 'Babyfood, mixed fruit yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf77d',
#   'fdc_id': 167726,
#   'description': 'Babyfood, mixed fruit yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf77e',
#   'fdc_id': 167726,
#   'description': 'Babyfood, mixed fruit yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf77f',
#   'fdc_id': 167726,
#   'description': 'Babyfood, mixed fruit yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf780',
#   'fdc_id': 167727,
#   'description': 'Beverages, ABBOTT, ENSURE PLUS, ready-to-drink'},
#  {'_id': '61955d4c0dfbbc31a2fdf781',
#   'fdc_id': 167727,
#   'description': 'Beverages, ABBOTT, ENSURE PLUS, ready-to-drink'},
#  {'_id': '61955d4c0dfbbc31a2fdf782',
#   'fdc_id': 167728,
#   'description': 'Babyfood, rice and apples, dry'},
#  {'_id': '61955d4c0dfbbc31a2fdf783',
#   'fdc_id': 167729,
#   'description': 'Babyfood, juice, apple - cherry'},
#  {'_id': '61955d4c0dfbbc31a2fdf784',
#   'fdc_id': 167729,
#   'description': 'Babyfood, juice, apple - cherry'},
#  {'_id': '61955d4c0dfbbc31a2fdf785',
#   'fdc_id': 167729,
#   'description': 'Babyfood, juice, apple - cherry'},
#  {'_id': '61955d4c0dfbbc31a2fdf786',
#   'fdc_id': 167729,
#   'description': 'Babyfood, juice, apple - cherry'},
#  {'_id': '61955d4c0dfbbc31a2fdf787',
#   'fdc_id': 167729,
#   'description': 'Babyfood, juice, apple - cherry'},
#  {'_id': '61955d4c0dfbbc31a2fdf788',
#   'fdc_id': 167730,
#   'description': 'Milk, imitation, non-soy'},
#  {'_id': '61955d4c0dfbbc31a2fdf789',
#   'fdc_id': 167730,
#   'description': 'Milk, imitation, non-soy'},
#  {'_id': '61955d4c0dfbbc31a2fdf78a',
#   'fdc_id': 167731,
#   'description': 'Babyfood, cereal, rice with pears and apple, dry, instant fortified'},
#  {'_id': '61955d4c0dfbbc31a2fdf78b',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf78c',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf78d',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf78e',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf78f',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf790',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf791',
#   'fdc_id': 167732,
#   'description': 'Babyfood, banana no tapioca, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf792',
#   'fdc_id': 167733,
#   'description': 'Babyfood, banana apple dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf793',
#   'fdc_id': 167733,
#   'description': 'Babyfood, banana apple dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf794',
#   'fdc_id': 167733,
#   'description': 'Babyfood, banana apple dessert, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdf795',
#   'fdc_id': 167734,
#   'description': 'Breakfast bar, corn flake crust with fruit'},
#  {'_id': '61955d4c0dfbbc31a2fdf796',
#   'fdc_id': 167734,
#   'description': 'Breakfast bar, corn flake crust with fruit'},
#  {'_id': '61955d4c0dfbbc31a2fdf797',
#   'fdc_id': 167735,
#   'description': 'Cheese, mozzarella, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf798',
#   'fdc_id': 167735,
#   'description': 'Cheese, mozzarella, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf799',
#   'fdc_id': 167735,
#   'description': 'Cheese, mozzarella, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf79a',
#   'fdc_id': 167735,
#   'description': 'Cheese, mozzarella, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdf79b',
#   'fdc_id': 167736,
#   'description': 'Mayonnaise dressing, no cholesterol'},
#  {'_id': '61955d4c0dfbbc31a2fdf79c',
#   'fdc_id': 167736,
#   'description': 'Mayonnaise dressing, no cholesterol'},
#  {'_id': '61955d4c0dfbbc31a2fdf79d',
#   'fdc_id': 167737,
#   'description': 'Oil, corn, peanut, and olive'},
#  {'_id': '61955d4c0dfbbc31a2fdf79e',
#   'fdc_id': 167737,
#   'description': 'Oil, corn, peanut, and olive'},
#  {'_id': '61955d4c0dfbbc31a2fdf79f',
#   'fdc_id': 167738,
#   'description': 'Pie fillings, blueberry, canned'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a0',
#   'fdc_id': 167738,
#   'description': 'Pie fillings, blueberry, canned'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a1',
#   'fdc_id': 167739,
#   'description': 'Beverages, Cocktail mix, non-alcoholic, concentrated, frozen'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a2',
#   'fdc_id': 167739,
#   'description': 'Beverages, Cocktail mix, non-alcoholic, concentrated, frozen'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a3',
#   'fdc_id': 167739,
#   'description': 'Beverages, Cocktail mix, non-alcoholic, concentrated, frozen'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a4',
#   'fdc_id': 167740,
#   'description': 'Puddings, chocolate flavor, low calorie, regular, dry mix'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a5',
#   'fdc_id': 167740,
#   'description': 'Puddings, chocolate flavor, low calorie, regular, dry mix'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a6',
#   'fdc_id': 167741,
#   'description': 'Puddings, all flavors except chocolate, low calorie, regular, dry mix'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a7',
#   'fdc_id': 167741,
#   'description': 'Puddings, all flavors except chocolate, low calorie, regular, dry mix'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a8',
#   'fdc_id': 167742,
#   'description': 'Mollusks, scallop, (bay and sea), cooked, steamed'},
#  {'_id': '61955d4c0dfbbc31a2fdf7a9',
#   'fdc_id': 167743,
#   'description': 'Syrup, Cane'},
#  {'_id': '61955d4c0dfbbc31a2fdf7aa',
#   'fdc_id': 167744,
#   'description': 'Mollusks, snail, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ab',
#   'fdc_id': 167745,
#   'description': 'Turtle, green, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ac',
#   'fdc_id': 167746,
#   'description': 'Lemons, raw, without peel'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ad',
#   'fdc_id': 167746,
#   'description': 'Lemons, raw, without peel'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ae',
#   'fdc_id': 167746,
#   'description': 'Lemons, raw, without peel'},
#  {'_id': '61955d4c0dfbbc31a2fdf7af',
#   'fdc_id': 167746,
#   'description': 'Lemons, raw, without peel'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b0',
#   'fdc_id': 167746,
#   'description': 'Lemons, raw, without peel'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b1',
#   'fdc_id': 167747,
#   'description': 'Lemon juice, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b2',
#   'fdc_id': 167747,
#   'description': 'Lemon juice, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b3',
#   'fdc_id': 167747,
#   'description': 'Lemon juice, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b4',
#   'fdc_id': 167747,
#   'description': 'Lemon juice, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b5',
#   'fdc_id': 167748,
#   'description': 'Lemon juice from concentrate, canned or bottled'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b6',
#   'fdc_id': 167748,
#   'description': 'Lemon juice from concentrate, canned or bottled'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b7',
#   'fdc_id': 167748,
#   'description': 'Lemon juice from concentrate, canned or bottled'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b8',
#   'fdc_id': 167748,
#   'description': 'Lemon juice from concentrate, canned or bottled'},
#  {'_id': '61955d4c0dfbbc31a2fdf7b9',
#   'fdc_id': 167749,
#   'description': 'Lemon peel, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ba',
#   'fdc_id': 167749,
#   'description': 'Lemon peel, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7bb',
#   'fdc_id': 167750,
#   'description': 'Prickly pears, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7bc',
#   'fdc_id': 167750,
#   'description': 'Prickly pears, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7bd',
#   'fdc_id': 167751,
#   'description': 'Plums, dried (prunes), stewed, without added sugar'},
#  {'_id': '61955d4c0dfbbc31a2fdf7be',
#   'fdc_id': 167752,
#   'description': 'Plums, dried (prunes), stewed, with added sugar'},
#  {'_id': '61955d4c0dfbbc31a2fdf7bf',
#   'fdc_id': 167753,
#   'description': 'Prune juice, canned'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c0',
#   'fdc_id': 167753,
#   'description': 'Prune juice, canned'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c1',
#   'fdc_id': 167754,
#   'description': 'Pummelo, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c2',
#   'fdc_id': 167754,
#   'description': 'Pummelo, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c3',
#   'fdc_id': 167755,
#   'description': 'Raspberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c4',
#   'fdc_id': 167755,
#   'description': 'Raspberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c5',
#   'fdc_id': 167755,
#   'description': 'Raspberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c6',
#   'fdc_id': 167756,
#   'description': 'Raspberries, canned, red, heavy syrup pack, solids and liquids'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c7',
#   'fdc_id': 167757,
#   'description': 'Raspberries, frozen, red, sweetened'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c8',
#   'fdc_id': 167757,
#   'description': 'Raspberries, frozen, red, sweetened'},
#  {'_id': '61955d4c0dfbbc31a2fdf7c9',
#   'fdc_id': 167758,
#   'description': 'Rhubarb, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ca',
#   'fdc_id': 167758,
#   'description': 'Rhubarb, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7cb',
#   'fdc_id': 167759,
#   'description': 'Sapodilla, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7cc',
#   'fdc_id': 167759,
#   'description': 'Sapodilla, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7cd',
#   'fdc_id': 167760,
#   'description': 'Sapote, mamey, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ce',
#   'fdc_id': 167760,
#   'description': 'Sapote, mamey, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7cf',
#   'fdc_id': 167761,
#   'description': 'Soursop, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d0',
#   'fdc_id': 167761,
#   'description': 'Soursop, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d1',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d2',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d3',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d4',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d5',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d6',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d7',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d8',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7d9',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7da',
#   'fdc_id': 167762,
#   'description': 'Strawberries, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7db',
#   'fdc_id': 167763,
#   'description': 'Tamarinds, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7dc',
#   'fdc_id': 167763,
#   'description': 'Tamarinds, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7dd',
#   'fdc_id': 167764,
#   'description': 'Fruit salad, (pineapple and papaya and banana and guava), tropical, canned, heavy syrup, solids and liquids'},
#  {'_id': '61955d4c0dfbbc31a2fdf7de',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7df',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e0',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e1',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e2',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e3',
#   'fdc_id': 167765,
#   'description': 'Watermelon, raw'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e4',
#   'fdc_id': 167766,
#   'description': 'Maraschino cherries, canned, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e5',
#   'fdc_id': 167767,
#   'description': 'Pineapple, canned, juice pack, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e6',
#   'fdc_id': 167767,
#   'description': 'Pineapple, canned, juice pack, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e7',
#   'fdc_id': 167767,
#   'description': 'Pineapple, canned, juice pack, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e8',
#   'fdc_id': 167767,
#   'description': 'Pineapple, canned, juice pack, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7e9',
#   'fdc_id': 167768,
#   'description': 'Apricots, canned, heavy syrup, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ea',
#   'fdc_id': 167768,
#   'description': 'Apricots, canned, heavy syrup, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7eb',
#   'fdc_id': 167769,
#   'description': 'Cherries, sour, canned, water pack, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ec',
#   'fdc_id': 167770,
#   'description': 'Cherries, sweet, canned, pitted, heavy syrup, drained'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ed',
#   'fdc_id': 167771,
#   'description': 'Apple juice, canned or bottled, unsweetened, with added ascorbic acid'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ee',
#   'fdc_id': 167771,
#   'description': 'Apple juice, canned or bottled, unsweetened, with added ascorbic acid'},
#  {'_id': '61955d4c0dfbbc31a2fdf7ef',
#   'fdc_id': 167772,
#   'description': 'Applesauce, canned, unsweetened, with added ascorbic acid'},
#  {'_id': '61955d4c0dfbbc31a2fdf7f0',
#   'fdc_id': 167773,
#   'description': 'Applesauce, canned, sweetened, with salt'},
#  {'_id': '61955d4c0dfbbc31a2fdf7f1',
#   'fdc_id': 167774,
# ...
#  {'_id': '61955d4c0dfbbc31a2fdf9c6',
#   'fdc_id': 168077,
#   'description': "DENNY'S, golden fried shrimp"},
#  {'_id': '61955d4c0dfbbc31a2fdf9c7',
#   'fdc_id': 168077,
#   'description': "DENNY'S, golden fried shrimp"},
#  {'_id': '61955d4c0dfbbc31a2fdf9c8',
#   'fdc_id': 168078,
#   'description': "DENNY'S, macaroni & cheese, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf9c9',
#   'fdc_id': 168078,
#   'description': "DENNY'S, macaroni & cheese, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf9ca',
#   'fdc_id': 168079,
#   'description': "DENNY'S, chicken nuggets, star shaped, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf9cb',
#   'fdc_id': 168079,
#   'description': "DENNY'S, chicken nuggets, star shaped, from kid's menu"},
#  {'_id': '61955d4c0dfbbc31a2fdf9cc',
#   'fdc_id': 168080,
#   'description': 'Restaurant, Chinese, shrimp and vegetables'},
#  {'_id': '61955d4c0dfbbc31a2fdf9cd',
#   'fdc_id': 168081,
#   'description': 'Restaurant, Chinese, sweet and sour chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ce',
#   'fdc_id': 168081,
#   'description': 'Restaurant, Chinese, sweet and sour chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf9cf',
#   'fdc_id': 168082,
#   'description': 'Restaurant, Chinese, sweet and sour pork'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d0',
#   'fdc_id': 168082,
#   'description': 'Restaurant, Chinese, sweet and sour pork'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d1',
#   'fdc_id': 168083,
#   'description': 'Restaurant, Chinese, chicken chow mein'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d2',
#   'fdc_id': 168084,
#   'description': 'Restaurant, Chinese, vegetable chow mein, without meat or noodles'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d3',
#   'fdc_id': 168084,
#   'description': 'Restaurant, Chinese, vegetable chow mein, without meat or noodles'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d4',
#   'fdc_id': 168085,
#   'description': 'OLIVE GARDEN, spaghetti with meat sauce'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d5',
#   'fdc_id': 168086,
#   'description': "CARRABBA'S ITALIAN GRILL, spaghetti with meat sauce"},
#  {'_id': '61955d4c0dfbbc31a2fdf9d6',
#   'fdc_id': 168087,
#   'description': 'Restaurant, Chinese, sesame chicken'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d7',
#   'fdc_id': 168088,
#   'description': 'Syrups, grenadine'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d8',
#   'fdc_id': 168088,
#   'description': 'Syrups, grenadine'},
#  {'_id': '61955d4c0dfbbc31a2fdf9d9',
#   'fdc_id': 168089,
#   'description': 'Imitation cheese, american or cheddar, low cholesterol'},
#  {'_id': '61955d4c0dfbbc31a2fdf9da',
#   'fdc_id': 168089,
#   'description': 'Imitation cheese, american or cheddar, low cholesterol'},
#  {'_id': '61955d4c0dfbbc31a2fdf9db',
#   'fdc_id': 168090,
#   'description': 'Babyfood, banana juice with low fat yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdf9dc',
#   'fdc_id': 168090,
#   'description': 'Babyfood, banana juice with low fat yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdf9dd',
#   'fdc_id': 168091,
#   'description': 'Babyfood, mixed fruit juice with low fat yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdf9de',
#   'fdc_id': 168091,
#   'description': 'Babyfood, mixed fruit juice with low fat yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdf9df',
#   'fdc_id': 168092,
#   'description': 'Ham, turkey, sliced, extra lean, prepackaged or deli'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e0',
#   'fdc_id': 168092,
#   'description': 'Ham, turkey, sliced, extra lean, prepackaged or deli'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e1',
#   'fdc_id': 168093,
#   'description': 'Salad dressing, peppercorn dressing, commercial, regular'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e2',
#   'fdc_id': 168093,
#   'description': 'Salad dressing, peppercorn dressing, commercial, regular'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e3',
#   'fdc_id': 168094,
#   'description': 'Mayonnaise, reduced-calorie or diet, cholesterol-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e4',
#   'fdc_id': 168094,
#   'description': 'Mayonnaise, reduced-calorie or diet, cholesterol-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e5',
#   'fdc_id': 168095,
#   'description': 'Granola bar, soft, milk chocolate coated, peanut butter'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e6',
#   'fdc_id': 168096,
#   'description': 'Salad dressing, italian dressing, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e7',
#   'fdc_id': 168096,
#   'description': 'Salad dressing, italian dressing, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e8',
#   'fdc_id': 168097,
#   'description': 'Cream substitute, liquid, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf9e9',
#   'fdc_id': 168097,
#   'description': 'Cream substitute, liquid, light'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ea',
#   'fdc_id': 168098,
#   'description': 'Cheese, monterey, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9eb',
#   'fdc_id': 168098,
#   'description': 'Cheese, monterey, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ec',
#   'fdc_id': 168098,
#   'description': 'Cheese, monterey, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ed',
#   'fdc_id': 168098,
#   'description': 'Cheese, monterey, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ee',
#   'fdc_id': 168099,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9ef',
#   'fdc_id': 168099,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, fat-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f0',
#   'fdc_id': 168100,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, cholesterol-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f1',
#   'fdc_id': 168100,
#   'description': 'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, cholesterol-free'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f2',
#   'fdc_id': 168101,
#   'description': 'Bologna, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f3',
#   'fdc_id': 168101,
#   'description': 'Bologna, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f4',
#   'fdc_id': 168101,
#   'description': 'Bologna, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f5',
#   'fdc_id': 168101,
#   'description': 'Bologna, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f6',
#   'fdc_id': 168101,
#   'description': 'Bologna, beef, low fat'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f7',
#   'fdc_id': 168102,
#   'description': 'Candies, MARS SNACKFOOD US, TWIX chocolate fudge cookie bars'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f8',
#   'fdc_id': 168103,
#   'description': 'Frozen yogurts, chocolate, nonfat milk, sweetened without sugar'},
#  {'_id': '61955d4c0dfbbc31a2fdf9f9',
#   'fdc_id': 168104,
#   'description': 'Frozen yogurts, chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf9fa',
#   'fdc_id': 168105,
#   'description': 'Frozen yogurts, flavors other than chocolate'},
#  {'_id': '61955d4c0dfbbc31a2fdf9fb',
#   'fdc_id': 168107,
#   'description': 'Rice cake, cracker (include hain mini rice cakes)'},
#  {'_id': '61955d4c0dfbbc31a2fdf9fc',
#   'fdc_id': 168108,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Almond Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf9fd',
#   'fdc_id': 168108,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Almond Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf9fe',
#   'fdc_id': 168108,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Almond Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdf9ff',
#   'fdc_id': 168108,
#   'description': "Candies, MARS SNACKFOOD US, M&M's Almond Chocolate Candies"},
#  {'_id': '61955d4c0dfbbc31a2fdfa00',
#   'fdc_id': 168109,
#   'description': 'Salad Dressing, coleslaw, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdfa01',
#   'fdc_id': 168109,
#   'description': 'Salad Dressing, coleslaw, reduced fat'},
#  {'_id': '61955d4c0dfbbc31a2fdfa02',
#   'fdc_id': 168110,
#   'description': 'Pork, cured, ham, low sodium, lean and fat, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdfa03',
#   'fdc_id': 168110,
#   'description': 'Pork, cured, ham, low sodium, lean and fat, cooked'},
#  {'_id': '61955d4c0dfbbc31a2fdfa04',
#   'fdc_id': 168111,
#   'description': 'Pork, cured, ham, boneless, low sodium, extra lean (approximately 5% fat), roasted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa05',
#   'fdc_id': 168111,
#   'description': 'Pork, cured, ham, boneless, low sodium, extra lean (approximately 5% fat), roasted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa06',
#   'fdc_id': 168112,
#   'description': 'Salad dressing, mayonnaise and mayonnaise-type, low calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdfa07',
#   'fdc_id': 168112,
#   'description': 'Salad dressing, mayonnaise and mayonnaise-type, low calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdfa08',
#   'fdc_id': 168113,
#   'description': 'Frozen novelties, juice type, orange'},
#  {'_id': '61955d4c0dfbbc31a2fdfa09',
#   'fdc_id': 168113,
#   'description': 'Frozen novelties, juice type, orange'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0a',
#   'fdc_id': 168114,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, no sodium added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0b',
#   'fdc_id': 168114,
#   'description': 'Cheese, cottage, lowfat, 1% milkfat, no sodium added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0c',
#   'fdc_id': 168115,
#   'description': 'Mayonnaise, low sodium, low calorie or diet'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0d',
#   'fdc_id': 168115,
#   'description': 'Mayonnaise, low sodium, low calorie or diet'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0e',
#   'fdc_id': 168116,
#   'description': 'Snacks, tortilla chips, unsalted, white corn'},
#  {'_id': '61955d4c0dfbbc31a2fdfa0f',
#   'fdc_id': 168116,
#   'description': 'Snacks, tortilla chips, unsalted, white corn'},
#  {'_id': '61955d4c0dfbbc31a2fdfa10',
#   'fdc_id': 168116,
#   'description': 'Snacks, tortilla chips, unsalted, white corn'},
#  {'_id': '61955d4c0dfbbc31a2fdfa11',
#   'fdc_id': 168117,
#   'description': 'Cranberry juice, unsweetened'},
#  {'_id': '61955d4c0dfbbc31a2fdfa12',
#   'fdc_id': 168117,
#   'description': 'Cranberry juice, unsweetened'},
#  {'_id': '61955d4c0dfbbc31a2fdfa13',
#   'fdc_id': 168118,
#   'description': 'Beef, bologna, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa14',
#   'fdc_id': 168118,
#   'description': 'Beef, bologna, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa15',
#   'fdc_id': 168118,
#   'description': 'Beef, bologna, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa16',
#   'fdc_id': 168118,
#   'description': 'Beef, bologna, reduced sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa17',
#   'fdc_id': 168119,
#   'description': 'Turnip greens, canned, no salt added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa18',
#   'fdc_id': 168120,
#   'description': 'Turkey, light or dark meat, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdfa19',
#   'fdc_id': 168120,
#   'description': 'Turkey, light or dark meat, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1a',
#   'fdc_id': 168120,
#   'description': 'Turkey, light or dark meat, smoked, cooked, with skin, bone removed'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1b',
#   'fdc_id': 168121,
#   'description': 'Cheese, pasteurized process, cheddar or American, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1c',
#   'fdc_id': 168121,
#   'description': 'Cheese, pasteurized process, cheddar or American, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1d',
#   'fdc_id': 168121,
#   'description': 'Cheese, pasteurized process, cheddar or American, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1e',
#   'fdc_id': 168121,
#   'description': 'Cheese, pasteurized process, cheddar or American, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa1f',
#   'fdc_id': 168122,
#   'description': 'Beverages, coffee, instant, with whitener, reduced calorie'},
#  {'_id': '61955d4c0dfbbc31a2fdfa20',
#   'fdc_id': 168123,
#   'description': 'Beverages, cranberry-apple juice drink, low calorie, with vitamin C added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa21',
#   'fdc_id': 168123,
#   'description': 'Beverages, cranberry-apple juice drink, low calorie, with vitamin C added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa22',
#   'fdc_id': 168124,
#   'description': 'Cheese, swiss, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa23',
#   'fdc_id': 168124,
#   'description': 'Cheese, swiss, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa24',
#   'fdc_id': 168124,
#   'description': 'Cheese, swiss, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa25',
#   'fdc_id': 168124,
#   'description': 'Cheese, swiss, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa26',
#   'fdc_id': 168125,
#   'description': 'Babyfood, dinner, macaroni, beef and tomato sauce, toddler'},
#  {'_id': '61955d4c0dfbbc31a2fdfa27',
#   'fdc_id': 168126,
#   'description': 'Rolls, pumpernickel'},
#  {'_id': '61955d4c0dfbbc31a2fdfa28',
#   'fdc_id': 168126,
#   'description': 'Rolls, pumpernickel'},
#  {'_id': '61955d4c0dfbbc31a2fdfa29',
#   'fdc_id': 168127,
#   'description': 'Snacks, corn-based, extruded, chips, unsalted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2a',
#   'fdc_id': 168127,
#   'description': 'Snacks, corn-based, extruded, chips, unsalted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2b',
#   'fdc_id': 168127,
#   'description': 'Snacks, corn-based, extruded, chips, unsalted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2c',
#   'fdc_id': 168128,
#   'description': 'Beans, baked, canned, no salt added'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2d',
#   'fdc_id': 168129,
#   'description': 'Jellyfish, dried, salted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2e',
#   'fdc_id': 168130,
#   'description': 'Frozen novelties, ice cream type, chocolate or caramel covered, with nuts'},
#  {'_id': '61955d4c0dfbbc31a2fdfa2f',
#   'fdc_id': 168131,
#   'description': 'Frankfurter, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa30',
#   'fdc_id': 168131,
#   'description': 'Frankfurter, low sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa31',
#   'fdc_id': 168132,
#   'description': 'Frozen novelties, ice type, pop, with low calorie sweetener'},
#  {'_id': '61955d4c0dfbbc31a2fdfa32',
#   'fdc_id': 168133,
#   'description': 'Babyfood, dessert, peach yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdfa33',
#   'fdc_id': 168133,
#   'description': 'Babyfood, dessert, peach yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdfa34',
#   'fdc_id': 168133,
#   'description': 'Babyfood, dessert, peach yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdfa35',
#   'fdc_id': 168133,
#   'description': 'Babyfood, dessert, peach yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdfa36',
#   'fdc_id': 168133,
#   'description': 'Babyfood, dessert, peach yogurt'},
#  {'_id': '61955d4c0dfbbc31a2fdfa37',
#   'fdc_id': 168134,
#   'description': 'Babyfood, dessert, blueberry yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa38',
#   'fdc_id': 168134,
#   'description': 'Babyfood, dessert, blueberry yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa39',
#   'fdc_id': 168134,
#   'description': 'Babyfood, dessert, blueberry yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3a',
#   'fdc_id': 168135,
#   'description': 'Babyfood, dessert, banana yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3b',
#   'fdc_id': 168135,
#   'description': 'Babyfood, dessert, banana yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3c',
#   'fdc_id': 168135,
#   'description': 'Babyfood, dessert, banana yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3d',
#   'fdc_id': 168135,
#   'description': 'Babyfood, dessert, banana yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3e',
#   'fdc_id': 168135,
#   'description': 'Babyfood, dessert, banana yogurt, strained'},
#  {'_id': '61955d4c0dfbbc31a2fdfa3f',
#   'fdc_id': 168136,
#   'description': 'Ice creams, chocolate, rich'},
#  {'_id': '61955d4c0dfbbc31a2fdfa40',
#   'fdc_id': 168136,
#   'description': 'Ice creams, chocolate, rich'},
#  {'_id': '61955d4c0dfbbc31a2fdfa41',
#   'fdc_id': 168137,
#   'description': 'Snacks, tortilla chips, light (baked with less oil)'},
#  {'_id': '61955d4c0dfbbc31a2fdfa42',
#   'fdc_id': 168137,
#   'description': 'Snacks, tortilla chips, light (baked with less oil)'},
#  {'_id': '61955d4c0dfbbc31a2fdfa43',
#   'fdc_id': 168138,
#   'description': 'Cereals ready-to-eat, POST, HONEY BUNCHES OF OATS, honey roasted'},
#  {'_id': '61955d4c0dfbbc31a2fdfa44',
#   'fdc_id': 168139,
#   'description': 'Popcorn, microwave, low fat and sodium'},
#  {'_id': '61955d4c0dfbbc31a2fdfa45',
#   'fdc_id': 168140,
#   'description': 'Babyfood, fruit supreme dessert'},
#  {'_id': '61955d4c0dfbbc31a2fdfa46',
#   'fdc_id': 168141,
#   'description': 'Cheese, swiss, low fat'},
#  ...]

# %%
df = pd.DataFrame(udf)

# %%
df.head()
# Out:
#                         _id  fdc_id  \
# 0  61955b150dfbbc31a2fdf65f  167512
# 1  61955d4c0dfbbc31a2fdf660  167512
# 2  61955d4c0dfbbc31a2fdf661  167513
# 3  61955d4c0dfbbc31a2fdf662  167514
# 4  61955d4c0dfbbc31a2fdf663  167515
#
#                                          description
# 0  Pillsbury Golden Layer Buttermilk Biscuits, Ar...
# 1  Pillsbury Golden Layer Buttermilk Biscuits, Ar...
# 2  Pillsbury, Cinnamon Rolls with Icing, refriger...
# 3  Kraft Foods, Shake N Bake Original Recipe, Coa...
# 4     George Weston Bakeries, Thomas English Muffins

# %%
def inlist (x):
    return list(x)

grupo = df.groupby(['description']).agg({'_id':inlist, 'fdc_id':inlist})

grupo.head()
# Out:
#                                                                                                   _id  \
# description
# APPLEBEE'S, 9 oz house sirloin steak                                       [61955d4c0dfbbc31a2fe05e1]
# APPLEBEE'S, Double Crunch Shrimp                                           [61955d4c0dfbbc31a2fe0040]
# APPLEBEE'S, KRAFT, Macaroni & Cheese, from kid'...  [61955d4c0dfbbc31a2fe0042, 61955d4c0dfbbc31a2f...
# APPLEBEE'S, chicken tenders platter                                        [61955d4c0dfbbc31a2fe05ef]
# APPLEBEE'S, chicken tenders, from kids' menu        [61955d4c0dfbbc31a2fe0046, 61955d4c0dfbbc31a2f...
#
#                                                               fdc_id
# description
# APPLEBEE'S, 9 oz house sirloin steak                        [169831]
# APPLEBEE'S, Double Crunch Shrimp                            [169008]
# APPLEBEE'S, KRAFT, Macaroni & Cheese, from kid'...  [169010, 169010]
# APPLEBEE'S, chicken tenders platter                         [169841]
# APPLEBEE'S, chicken tenders, from kids' menu        [169012, 169012]

# %%
import json 

with open( './csv/legacy.json', 'r') as f:
    contents = json.loads (f.read())
    data = json.load(f)

post = dict()
for row in contents:
    post = row
    break

# %%
with open( './csv/legacy.json', 'r') as f:
    dados = json.load(f)

db.test.insert_many(dados)

# %%
import re

cursor = list(db.data.find({'description':{"$regex":re.compile('cracker.+', re.IGNORECASE)}}, max_time_ms=1000))

for item in cursor:
    print(item['description'], item['portion'])
    d = dict(item)
    for k, v in  d['nutrients'].items():
        print(v['nutrient_name'],'-',v['nutrient_amount'], v['nutrient_unit'].lower() )

    break

# %%
post_id = data.insert_one(post).inserted_id

# %%
result

# %%
print(ObjectId('61955b150dfbbc31a2fdf65f'))
# Out:
# 61955b150dfbbc31a2fdf65f

# %%
from bson.objectid import ObjectId
def get(post_id):
    # Convert from string to ObjectId:
    document = client.db.collection.find_one({'_id': ObjectId(post_id)})

# %%
#connect to MongoDB Cloud Atlas
from pymongo import MongoClient

user = 'dbadmin'
password = 'mongoatlas1305'
client = MongoClient(f"mongodb+srv://{user}:{password}@cluster0.cxvpd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
import json

with open( './csv/legacy.json', 'r') as f:
    dados = json.load(f)

db.legacy.insert_many(dados)

# %%
db.list_collection_names()
# Out:
# []
